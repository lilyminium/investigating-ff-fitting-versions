# %%
import re
import pathlib
import tqdm
import numpy as np
import pandas as pd
import MDAnalysis as mda
from openff.toolkit.topology.molecule import Molecule, unit
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
def get_smiles(batch_name: str, target_name: str):
    from openff.toolkit.topology import Molecule
    
    target_directory = pathlib.Path("../targets")
    
    if batch_name.startswith("opt"):
        file = target_directory / batch_name / f"{target_name}.sdf"
    else:
        file = target_directory / target_name / "input.sdf"
    
    mol = Molecule.from_file(str(file.resolve()), "SDF", allow_undefined_stereo=True)
    return mol.to_smiles(mapped=True), mol.to_smiles()

# %%
def read_indicate(logfile):
    import pandas as pd
    
    logfile = pathlib.Path(logfile)

    data = {
        "Target type": [],
        "Batch": [],
        "Target name": [],
        "QCArchive ID": [],
        "Batch ID": [],
        "Mapped SMILES": [],
        "SMILES": [],
        "Term": [],
    }
    with logfile.open("r") as f:
        contents = [x.strip() for x in f.readlines()]
    for line in contents:
        fields = line.split()
        if not fields or not len(re.findall("-", fields[0])) == 1:
            continue
        name = fields[0]
        if name.startswith("torsion"):
            qcarchive_id = name.split("-")[1]
            batch_id = -1
            term_type = "torsion"
            continue
        else:
            qcarchive_id, batch_id = name.split("-")
            term_type = "optgeo"

        batch_name = logfile.parent.parent.stem
        term = float(fields[-1])
        mapped_smiles, smiles = get_smiles(batch_name, name)

        data["Target type"].append(term_type)
        data["Batch"].append(batch_name)
        data["Target name"].append(name)
        data["QCArchive ID"].append(int(qcarchive_id))
        data["Batch ID"].append(int(batch_id))
        data["Mapped SMILES"].append(mapped_smiles)
        data["SMILES"].append(smiles)
        data["Term"].append(term)
    
    df = pd.DataFrame(data)
    df.index = df["Target name"]
    
    directory = logfile.parent.parent.parent.parent
    df["Replicate"] = directory.stem
    df["Environment"] = directory.parent.stem
    df["Project"] = directory.parent.parent.stem
    return df

# %%
def read_all():
    here = pathlib.Path(".")
    indicate_logs = sorted(here.glob("*/*/*/optimize.tmp/*/iter_0000/indicate.log"))
    
    dfs = []
    for logfile in tqdm.tqdm(indicate_logs):
        dfs.append(read_indicate(logfile))
    df = pd.concat(dfs)
    return df

# %%
df = read_all()
# Out:
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊  | 30326/30761 [25:06<01:00,  7.14it/s]

# %%
df.to_csv("all_targets.csv")

# %%
df

# %%
df.columns

# %%
opt_columns = [
    'Batch', 'QCArchive ID', 'Batch ID',
   'Mapped SMILES', 'SMILES', 'Term', 'Replicate', 'Environment',
   'Project'
]

# %%
opt_df = pd.DataFrame(
    df[df["Target type"] == "optgeo"][opt_columns]
)

# %%
def get_rmsd(
    batch_name: str,
    target_name: str,
    project_a: str,
    environment_a: str,
    replicate_a: str,
    project_b: str,
    environment_b: str,
    replicate_b: str
):
    from rdkit import Chem
    from rdkit.Chem import AllChem
    from MDAnalysis.analysis import rms
    
    mapped_smiles, _ = get_smiles(batch_name, target_name)
    
    mol = Molecule.from_mapped_smiles(mapped_smiles, allow_undefined_stereo=True)
    
    xyz_subpath = f"optimize.tmp/{batch_name}/iter_0000/{target_name}_mmopt.xyz"
    xyz_a = pathlib.Path(project_a) / environment_a / replicate_a / xyz_subpath
    xyz_b = pathlib.Path(project_b) / environment_b / replicate_b / xyz_subpath
    
    conformer_a = np.array(mda.Universe(xyz_a).atoms.positions).astype(float)
    conformer_b = np.array(mda.Universe(xyz_b).atoms.positions).astype(float)
    
    rmsd = rms.rmsd(conformer_a, conformer_b)
    
    mol._conformers = [conformer_a * unit.angstrom]
    rdmol_a = mol.to_rdkit()
    
    mol._conformers = [conformer_b * unit.angstrom]
    rdmol_b = mol.to_rdkit()
    
    best_rmsd = AllChem.GetBestRMS(rdmol_a, rdmol_b)
    return rmsd, best_rmsd

# %% [markdown]
# ## Non-1.9.6 differences

# %%
potential_problem_targets = {}
consistent = []

opt_df_not_196 = opt_df[opt_df.Environment != "fb-196-ic-0318-oe-2022"]
for (batch_id, target_name), subdf in opt_df_not_196.groupby(by=["Batch", "Target name"]):
    unique_terms = subdf.Term.unique()
    difference = subdf.Term.max() - subdf.Term.min()
    if difference > 0.001:
        potential_problem_targets[(batch_id, target_name)] = subdf
    else:
        consistent.append((batch_id, target_name))

# %%
len(potential_problem_targets)
# Out:
# 666

# %%
keys = list(potential_problem_targets.keys())

# %%
key = keys[1]
key
# Out:
# ('opt-geo-batch-1', '18433053-13')

# %%
potential_problem_targets[key].Term.values
# Out:
# array([555.896, 555.896, 555.896, 555.896, 555.896, 555.896, 555.897,
#        555.897, 555.897, 555.896, 555.896, 555.896, 555.896, 555.896,
#        555.896, 555.897, 555.897, 555.897, 555.896, 555.896, 555.896,
#        555.896, 555.896, 555.896, 555.897, 555.897, 555.897])

# %%
help(get_rmsd)
# Out:
# Help on function get_rmsd in module __main__:
#
# get_rmsd(batch_name: str, target_name: str, project_a: str, environment_a: str, replicate_a: str, project_b: str, environment_b: str, replicate_b: str)

# %%
project = potential_problem_targets[key].Project.values[-1]
get_rmsd(
    *key,
    project_a=project,
    environment_a="fb-193-tk-010-oe-2022-reordered",
    replicate_a="rep1",
    project_b=project,
    environment_b="fb-195-tk-013-oe-2022-interchange-replace-cache",
    replicate_b="rep1",
)
# Out:
# (1.1425002725123635e-06, 1.1101660563055304e-06)

# %%
rmsd_difference = {
    "Difference": [],
    "RMSD": [],
    "Best RMSD": []
}

for key in tqdm.tqdm(potential_problem_targets):
    a = "fb-193-tk-010-oe-2022-reordered"
    b = "fb-195-tk-013-oe-2022-interchange-replace-cache"
    subdf = potential_problem_targets[key]
    sub_a = subdf[subdf.Environment == a]
    sub_b = subdf[subdf.Environment == b]
    difference = abs(sub_a.Term.values[0] - sub_b.Term.values[0])
    project = subdf.Project.values[-1]
    rmsd, best_rmsd = get_rmsd(
        *key,
        project_a=project,
        environment_a=a,
        replicate_a="rep1",
        project_b=project,
        environment_b=b,
        replicate_b="rep1",
    )
    
    rmsd_difference["Difference"].append(difference)
    rmsd_difference["RMSD"].append(rmsd)
    rmsd_difference["Best RMSD"].append(best_rmsd)

rmsd_difference_df = pd.DataFrame(rmsd_difference)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 666/666 [08:09<00:00,  1.36it/s]

# %%
rmsd_difference_df.to_csv("rmsd-vs-objective_193-vs-195.csv")

# %%
diff_001 = rmsd_difference_df[rmsd_difference_df.Difference <= 0.0011]
print(diff_001.RMSD.min(), diff_001.RMSD.max())
print(diff_001["Best RMSD"].min(), diff_001["Best RMSD"].max())
# Out:
# 7.99564522107703e-08 5.3510634345326214e-05
# 0.0 5.3504443958427124e-05

# %%
diff_002 = rmsd_difference_df[
    (rmsd_difference_df.Difference > 0.0011)
    & (rmsd_difference_df.Difference <= 0.0021)
]
print(diff_002.RMSD.min(), diff_002.RMSD.max())
print(diff_002["Best RMSD"].min(), diff_002["Best RMSD"].max())
# Out:
# 5.497979818346711e-07 7.2445385466706e-05
# 5.277620225233711e-07 7.244401154226771e-05

# %%
rmsd_difference_df.Difference.max()
# Out:
# 1030.8169999999998

# %%
for counter in range(100):
    low = 0.0001 + (counter * 0.1)
    high = low + 0.1
    subdf = rmsd_difference_df[
        (rmsd_difference_df.Difference > low)
        & (rmsd_difference_df.Difference <= high)
    ]
    if not len(subdf):
        continue
    rmsd_low = subdf["RMSD"].min()
    rmsd_high = subdf["RMSD"].max()
    best_rmsd_low = subdf["Best RMSD"].min()
    best_rmsd_high = subdf["Best RMSD"].max()
    print(f"{low:.3f}-{high:.3f},{rmsd_low:.0e} to {rmsd_high:.0e},{best_rmsd_low:.0e} to {best_rmsd_high:.0e}")
# Out:
# 0.000-0.100,8e-08 to 6e-04,0e+00 to 6e-04
# 0.100-0.200,6e-05 to 8e-04,6e-05 to 8e-04
# 0.200-0.300,5e-04 to 8e-04,5e-04 to 8e-04
# 0.300-0.400,4e-04 to 4e-04,4e-04 to 4e-04
# 7.500-7.600,1e-01 to 1e-01,1e-01 to 1e-01

# %% [markdown]
# ## Between-rep differences

# %%
potential_problem_targets_all = {}
consistent_all = []
for (batch_id, target_name), subdf in opt_df.groupby(by=["Batch", "Target name"]):
    difference = subdf.Term.max() - subdf.Term.min()
    if difference > 5:
        potential_problem_targets_all[(batch_id, target_name)] = subdf
    else:
        consistent_all.append((batch_id, target_name))

# %%
len(potential_problem_targets_all)
# Out:
# 44

# %%
len(consistent_all)
# Out:
# 5394

# %%
keys = list(potential_problem_targets_all.keys())

# %%
key = keys[0]
key
# Out:
# ('opt-geo-batch-108', '19095393-10')

# %%
potential_problem_targets_all[key]
# Out:
#                          Batch  QCArchive ID  Batch ID  \
# Target name
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
# 19095393-10  opt-geo-batch-108    19095393.0      10.0
#
#                                                  Mapped SMILES  \
# Target name
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
# 19095393-10  [H:35][c:1]1[c:3]([c:9]([c:7]([n:27][c:6]1[H:4...
#
#                                                         SMILES    Term  \
# Target name
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  85.713
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
# 19095393-10  [H]c1c(c(c(nc1[H])[H])C([H])([H])N([H])C(=O)c2...  46.043
#
#             Replicate                                        Environment  \
# Target name
# 19095393-10      rep1                              fb-193-tk-010-oe-2022
# 19095393-10      rep2                              fb-193-tk-010-oe-2022
# 19095393-10      rep3                              fb-193-tk-010-oe-2022
# 19095393-10      rep1                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep2                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep3                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep1    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep2    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep3    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep1  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep2  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep3  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep1                             fb-196-ic-0318-oe-2022
# 19095393-10      rep2                             fb-196-ic-0318-oe-2022
# 19095393-10      rep3                             fb-196-ic-0318-oe-2022
# 19095393-10      rep1                        fb-196-ic-0318-oe-2022-crit
# 19095393-10      rep2                        fb-196-ic-0318-oe-2022-crit
# 19095393-10      rep3                        fb-196-ic-0318-oe-2022-crit
# 19095393-10      rep1                              fb-193-tk-010-oe-2022
# 19095393-10      rep2                              fb-193-tk-010-oe-2022
# 19095393-10      rep3                              fb-193-tk-010-oe-2022
# 19095393-10      rep1                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep2                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep3                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep1    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep2    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep3    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep1  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep2  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep3  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 19095393-10      rep1                             fb-196-ic-0318-oe-2022
# 19095393-10      rep2                             fb-196-ic-0318-oe-2022
# 19095393-10      rep3                             fb-196-ic-0318-oe-2022
# 19095393-10      rep1                              fb-193-tk-010-oe-2022
# 19095393-10      rep2                              fb-193-tk-010-oe-2022
# 19095393-10      rep3                              fb-193-tk-010-oe-2022
# 19095393-10      rep1                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep2                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep3                    fb-193-tk-010-oe-2022-reordered
# 19095393-10      rep1    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep2    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep3    fb-195-tk-013-oe-2022-interchange-replace-cache
# 19095393-10      rep1                             fb-196-ic-0318-oe-2022
# 19095393-10      rep2                             fb-196-ic-0318-oe-2022
# 19095393-10      rep3                             fb-196-ic-0318-oe-2022
#
#                            Project
# Target name
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            001_fit-all
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10            002_fit-opt
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108
# 19095393-10  111_opt-geo-batch-108

# %%
target_rows = []

for key in keys:
    subdf = potential_problem_targets_all[key]
    for project, project_df in subdf.groupby("Project"):
        row = {"Batch": key[0], "Target": key[1], "Project": project}
        for env, env_df in project_df.groupby("Environment"):
            row[env] = env_df.Term.values[0]
        target_rows.append(row)

target_df = pd.DataFrame.from_records(target_rows)

# %%
target_df
# Out:
#                  Batch       Target                Project  \
# 0    opt-geo-batch-108  19095393-10            001_fit-all
# 1    opt-geo-batch-108  19095393-10            002_fit-opt
# 2    opt-geo-batch-108  19095393-10  111_opt-geo-batch-108
# 3    opt-geo-batch-109   19095414-4            001_fit-all
# 4    opt-geo-batch-109   19095414-4            002_fit-opt
# ..                 ...          ...                    ...
# 127   opt-geo-batch-96  19095011-20            002_fit-opt
# 128   opt-geo-batch-96  19095011-20   099_opt-geo-batch-96
# 129   opt-geo-batch-96  19095014-23            001_fit-all
# 130   opt-geo-batch-96  19095014-23            002_fit-opt
# 131   opt-geo-batch-96  19095014-23   099_opt-geo-batch-96
#
#      fb-193-tk-010-oe-2022  fb-193-tk-010-oe-2022-reordered  \
# 0                   85.713                           85.713
# 1                   85.713                           85.713
# 2                   85.713                           85.713
# 3                  973.288                          678.567
# 4                  973.288                          678.567
# ..                     ...                              ...
# 127               1561.274                         2592.095
# 128               1561.274                         2592.095
# 129                239.718                         1177.130
# 130                239.718                         1177.130
# 131                239.718                         1177.130
#
#      fb-195-tk-013-oe-2022-interchange-replace-cache  \
# 0                                             85.713
# 1                                             85.713
# 2                                             85.713
# 3                                            678.565
# 4                                            678.565
# ..                                               ...
# 127                                         1561.278
# 128                                         1561.278
# 129                                          239.723
# 130                                          239.723
# 131                                          239.723
#
#      fb-195-tk-013-oe-2022-interchange-replace-cache-switching  \
# 0                                               85.713
# 1                                               85.713
# 2                                                  NaN
# 3                                              678.565
# 4                                              678.565
# ..                                                 ...
# 127                                           1561.278
# 128                                                NaN
# 129                                            239.723
# 130                                            239.723
# 131                                                NaN
#
#      fb-196-ic-0318-oe-2022  fb-196-ic-0318-oe-2022-crit
# 0                    46.043                       85.713
# 1                    46.043                          NaN
# 2                    46.043                          NaN
# 3                   678.593                      678.565
# 4                   678.593                          NaN
# ..                      ...                          ...
# 127                1561.667                          NaN
# 128                1561.667                          NaN
# 129                 239.679                      239.723
# 130                 239.679                          NaN
# 131                 239.679                          NaN
#
# [132 rows x 9 columns]

# %%
(target_df["fb-196-ic-0318-oe-2022-crit"] - target_df["fb-196-ic-0318-oe-2022"]).sum()
# Out:
# 1183.8810000000008

# %%
target_df.to_csv("target_differences.csv")

# %%
target_df_1 = target_df[target_df.Project == "001_fit-all"]

# %%
target_df_1.to_csv("target_differences_1.csv")

# %%
target_df_1
# Out:
#                  Batch        Target      Project  fb-193-tk-010-oe-2022  \
# 0    opt-geo-batch-108   19095393-10  001_fit-all                 85.713
# 3    opt-geo-batch-109    19095414-4  001_fit-all                973.288
# 6    opt-geo-batch-113    19095588-8  001_fit-all                800.755
# 9    opt-geo-batch-115    19095648-2  001_fit-all                241.176
# 12   opt-geo-batch-123    19095890-3  001_fit-all                432.754
# 15   opt-geo-batch-125   19095964-29  001_fit-all                557.615
# 18   opt-geo-batch-127   95602811-22  001_fit-all                828.404
# 21   opt-geo-batch-131    95602486-3  001_fit-all                169.287
# 24   opt-geo-batch-132   110312272-7  001_fit-all                 44.947
# 27   opt-geo-batch-132  110312279-12  001_fit-all                 19.782
# 30   opt-geo-batch-134   110312364-2  001_fit-all                 35.291
# 33   opt-geo-batch-134  110312437-22  001_fit-all                536.681
# 36   opt-geo-batch-136   110312530-8  001_fit-all                796.962
# 39   opt-geo-batch-142    1760118-25  001_fit-all                 32.291
# 42   opt-geo-batch-142    1760122-29  001_fit-all                 37.563
# 45   opt-geo-batch-158    1760623-13  001_fit-all                 52.588
# 48   opt-geo-batch-160    1760689-13  001_fit-all                 10.233
# 51   opt-geo-batch-162    1760764-24  001_fit-all                 14.742
# 54   opt-geo-batch-162    1760765-26  001_fit-all                 16.341
# 57   opt-geo-batch-165    1760859-25  001_fit-all                184.378
# 60   opt-geo-batch-166    1760895-28  001_fit-all                 16.898
# 63   opt-geo-batch-181   36784452-26  001_fit-all                 85.997
# 66    opt-geo-batch-19   18434757-17  001_fit-all               1352.305
# 69    opt-geo-batch-20    18434815-6  001_fit-all                 83.565
# 72    opt-geo-batch-20    18434816-9  001_fit-all                 71.022
# 75    opt-geo-batch-21    18434921-7  001_fit-all               1805.074
# 78    opt-geo-batch-28   18435721-28  001_fit-all                333.911
# 81    opt-geo-batch-36    18436551-7  001_fit-all                 20.981
# 84    opt-geo-batch-48   18437974-17  001_fit-all               2097.572
# 87     opt-geo-batch-5   18433236-22  001_fit-all                654.976
# 90    opt-geo-batch-51   18438135-12  001_fit-all                794.575
# 93    opt-geo-batch-51   18438149-18  001_fit-all                100.882
# 96    opt-geo-batch-58    18438954-4  001_fit-all                661.058
# 99    opt-geo-batch-64   18439704-15  001_fit-all                 17.706
# 102   opt-geo-batch-71   19094129-20  001_fit-all                470.715
# 105   opt-geo-batch-75   19094250-10  001_fit-all                480.939
# 108   opt-geo-batch-78    19094395-8  001_fit-all                327.768
# 111   opt-geo-batch-79   19094430-15  001_fit-all                119.851
# 114   opt-geo-batch-79   19094441-17  001_fit-all                 84.345
# 117   opt-geo-batch-83   19094564-15  001_fit-all                662.573
# 120   opt-geo-batch-83   95602606-12  001_fit-all                352.848
# 123   opt-geo-batch-91    19094843-7  001_fit-all                523.362
# 126   opt-geo-batch-96   19095011-20  001_fit-all               1561.274
# 129   opt-geo-batch-96   19095014-23  001_fit-all                239.718
#
#      fb-193-tk-010-oe-2022-reordered  \
# 0                             85.713
# 3                            678.567
# 6                            488.803
# 9                            592.293
# 12                           859.172
# 15                           557.896
# 18                           371.009
# 21                           395.607
# 24                            44.947
# 27                            19.782
# 30                            35.291
# 33                           831.782
# 36                          1886.145
# 39                            32.291
# 42                            37.565
# 45                            52.588
# 48                            10.233
# 51                            14.742
# 54                            16.341
# 57                           184.378
# 60                            16.898
# 63                            85.997
# 66                          2589.068
# 69                            83.565
# 72                            71.022
# 75                          1389.509
# 78                           333.910
# 81                            20.981
# 84                           442.100
# 87                           819.474
# 90                          1409.209
# 93                           108.452
# 96                           661.059
# 99                            17.706
# 102                          470.715
# 105                          150.779
# 108                          327.768
# 111                          119.701
# 114                           84.096
# 117                          411.628
# 120                          609.252
# 123                         1019.271
# 126                         2592.095
# 129                         1177.130
#
#      fb-195-tk-013-oe-2022-interchange-replace-cache  \
# 0                                             85.713
# 3                                            678.565
# 6                                            488.803
# 9                                            241.176
# 12                                           424.808
# 15                                           557.836
# 18                                           828.402
# 21                                           169.287
# 24                                            44.947
# 27                                            19.782
# 30                                            35.291
# 33                                           536.684
# 36                                          1886.142
# 39                                            32.291
# 42                                            37.563
# 45                                            52.588
# 48                                            10.233
# 51                                            14.742
# 54                                            16.341
# 57                                           184.378
# 60                                            16.898
# 63                                            85.997
# 66                                          1744.044
# 69                                           126.754
# 72                                           169.281
# 75                                          1805.075
# 78                                           333.910
# 81                                            20.981
# 84                                           442.121
# 87                                           654.976
# 90                                           794.575
# 93                                           100.882
# 96                                           661.060
# 99                                            17.706
# 102                                          117.418
# 105                                          480.940
# 108                                          862.083
# 111                                          120.066
# 114                                           84.232
# 117                                          411.628
# 120                                          609.256
# 123                                          523.364
# 126                                         1561.278
# 129                                          239.723
#
#      fb-195-tk-013-oe-2022-interchange-replace-cache-switching  \
# 0                                               85.713
# 3                                              678.565
# 6                                              488.803
# 9                                              241.176
# 12                                             424.808
# 15                                             557.836
# 18                                             828.402
# 21                                             169.287
# 24                                              44.947
# 27                                              19.782
# 30                                              35.291
# 33                                             536.684
# 36                                            1886.142
# 39                                              32.291
# 42                                              37.563
# 45                                              52.588
# 48                                              10.233
# 51                                              14.742
# 54                                              16.341
# 57                                             184.378
# 60                                              16.898
# 63                                              85.997
# 66                                            1744.044
# 69                                             126.754
# 72                                             169.281
# 75                                            1805.075
# 78                                             333.910
# 81                                              20.981
# 84                                             442.121
# 87                                             654.976
# 90                                             794.575
# 93                                             100.882
# 96                                             661.060
# 99                                              17.706
# 102                                            117.418
# 105                                            480.940
# 108                                            862.083
# 111                                            120.066
# 114                                             84.232
# 117                                            411.628
# 120                                            609.256
# 123                                            523.364
# 126                                           1561.278
# 129                                            239.723
#
#      fb-196-ic-0318-oe-2022  fb-196-ic-0318-oe-2022-crit
# 0                    46.043                       85.713
# 3                   678.593                      678.565
# 6                   488.806                      488.803
# 9                   241.209                      241.176
# 12                  424.811                      424.808
# 15                  527.510                      557.836
# 18                  828.471                      828.402
# 21                  169.288                      169.287
# 24                   19.051                       44.947
# 27                   11.507                       19.782
# 30                   24.732                       35.291
# 33                  541.105                      536.684
# 36                 1885.838                     1886.142
# 39                    5.104                       32.291
# 42                   10.582                       37.563
# 45                   10.515                       52.588
# 48                    2.921                       10.233
# 51                    6.441                       14.742
# 54                    4.872                       16.341
# 57                    8.331                      184.378
# 60                    5.847                       16.898
# 63                   43.280                       85.997
# 66                 1743.914                     1744.044
# 69                  126.789                      126.754
# 72                  169.253                      169.281
# 75                 1805.138                     1805.075
# 78                  320.960                      333.910
# 81                    9.047                       20.981
# 84                  441.091                      442.121
# 87                  654.977                      654.976
# 90                  794.554                      794.575
# 93                  100.882                      100.882
# 96                    9.408                      661.060
# 99                    7.980                       17.706
# 102                 117.415                      117.418
# 105                 480.970                      480.940
# 108                 862.083                      862.083
# 111                 101.136                      120.066
# 114                  69.599                       84.232
# 117                 411.699                      411.628
# 120                 609.277                      609.256
# 123                 523.564                      523.364
# 126                1561.667                     1561.278
# 129                 239.679                      239.723

# %%
df[
    (df["Target name"] == "18438954-4")
    & (df["Project"] == "001_fit-all")
]
# Out:
#             Target type             Batch Target name  QCArchive ID  Batch ID  \
# Target name
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
# 18438954-4       optgeo  opt-geo-batch-58  18438954-4    18438954.0       4.0
#
#                                                  Mapped SMILES  \
# Target name
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
# 18438954-4   [H:16][c:1]1[c:2]([c:4]([c:6]([c:5]([c:3]1[H:1...
#
#                                                         SMILES     Term  \
# Target name
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.058
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.058
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.058
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.059
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.059
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.059
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...    9.408
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...    9.408
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...    9.408
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
# 18438954-4   [H]c1c(c(c(c(c1[H])[H])SC2=NC(=NN2[H])[N+](=O)...  661.060
#
#             Replicate                                        Environment  \
# Target name
# 18438954-4       rep1                              fb-193-tk-010-oe-2022
# 18438954-4       rep2                              fb-193-tk-010-oe-2022
# 18438954-4       rep3                              fb-193-tk-010-oe-2022
# 18438954-4       rep1                    fb-193-tk-010-oe-2022-reordered
# 18438954-4       rep2                    fb-193-tk-010-oe-2022-reordered
# 18438954-4       rep3                    fb-193-tk-010-oe-2022-reordered
# 18438954-4       rep1    fb-195-tk-013-oe-2022-interchange-replace-cache
# 18438954-4       rep2    fb-195-tk-013-oe-2022-interchange-replace-cache
# 18438954-4       rep3    fb-195-tk-013-oe-2022-interchange-replace-cache
# 18438954-4       rep1  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 18438954-4       rep2  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 18438954-4       rep3  fb-195-tk-013-oe-2022-interchange-replace-cach...
# 18438954-4       rep1                             fb-196-ic-0318-oe-2022
# 18438954-4       rep2                             fb-196-ic-0318-oe-2022
# 18438954-4       rep3                             fb-196-ic-0318-oe-2022
# 18438954-4       rep1                        fb-196-ic-0318-oe-2022-crit
# 18438954-4       rep2                        fb-196-ic-0318-oe-2022-crit
# 18438954-4       rep3                        fb-196-ic-0318-oe-2022-crit
#
#                  Project
# Target name
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all
# 18438954-4   001_fit-all

# %% [markdown]
# ## 1.9.5 differences

# %%
help(get_rmsd)
# Out:
# Help on function get_rmsd in module __main__:
#
# get_rmsd(batch_name: str, target_name: str, project_a: str, environment_a: str, replicate_a: str, project_b: str, environment_b: str, replicate_b: str)

# %%
def cross_compare(
    batch_id,
    target_name,
    project="001_fit-all",
    replicate="rep1",
):
    envs = [
        "fb-193-tk-010-oe-2022",
        "fb-193-tk-010-oe-2022-reordered",
        "fb-195-tk-013-oe-2022-interchange-replace-cache",
        "fb-195-tk-013-oe-2022-interchange-replace-cache-switching",
        "fb-196-ic-0318-oe-2022",
    ]
    data = {}
    for env in envs:
        data[env] = dict.fromkeys(envs, 0)
    for i, env_a in enumerate(envs):
        for j, env_b in enumerate(envs[i+1:], i+1):
            rmsd, best_rmsd = get_rmsd(
                batch_id,
                target_name,
                project_a=project,
                environment_a=env_a,
                replicate_a=replicate,
                project_b=project,
                environment_b=env_b,
                replicate_b=replicate,
            )
            data[env_a][env_b] = rmsd
            data[env_b][env_a] = best_rmsd
    rmsd_df = pd.DataFrame.from_records(data)
    rmsd_df.to_csv(f"rmsd_cross_compare/{batch_id}_{target_name}.csv")
    return rmsd_df

# %%
df_19_17 = cross_compare("opt-geo-batch-19", "18434757-17")

# %%
df_19_17
# Out:
#                                                  fb-193-tk-010-oe-2022  \
# fb-193-tk-010-oe-2022                                         0.000000
# fb-193-tk-010-oe-2022-reordered                               0.542704
# fb-195-tk-013-oe-2022-interchange-replace-cache               0.306250
# fb-196-ic-0318-oe-2022                                        0.306197
#
#                                                  fb-193-tk-010-oe-2022-reordered  \
# fb-193-tk-010-oe-2022                                               8.041106e-07
# fb-193-tk-010-oe-2022-reordered                                     0.000000e+00
# fb-195-tk-013-oe-2022-interchange-replace-cache                     3.323345e-01
# fb-196-ic-0318-oe-2022                                              3.323941e-01
#
#                                                  fb-195-tk-013-oe-2022-interchange-replace-cache  \
# fb-193-tk-010-oe-2022                                                                   0.304596
# fb-193-tk-010-oe-2022-reordered                                                         0.304597
# fb-195-tk-013-oe-2022-interchange-replace-cache                                         0.000000
# fb-196-ic-0318-oe-2022                                                                  0.000075
#
#                                                  fb-196-ic-0318-oe-2022
# fb-193-tk-010-oe-2022                                          0.304540
# fb-193-tk-010-oe-2022-reordered                                0.304540
# fb-195-tk-013-oe-2022-interchange-replace-cache                0.000069
# fb-196-ic-0318-oe-2022                                         0.000000

# %%
df_20_6 = cross_compare("opt-geo-batch-20", "18434815-6")
df_20_6
# Out:
#                                                  fb-193-tk-010-oe-2022  \
# fb-193-tk-010-oe-2022                                         0.000000
# fb-193-tk-010-oe-2022-reordered                               0.000001
# fb-195-tk-013-oe-2022-interchange-replace-cache               0.264472
# fb-196-ic-0318-oe-2022                                        0.264514
#
#                                                  fb-193-tk-010-oe-2022-reordered  \
# fb-193-tk-010-oe-2022                                                   0.000001
# fb-193-tk-010-oe-2022-reordered                                         0.000000
# fb-195-tk-013-oe-2022-interchange-replace-cache                         0.264472
# fb-196-ic-0318-oe-2022                                                  0.264514
#
#                                                  fb-195-tk-013-oe-2022-interchange-replace-cache  \
# fb-193-tk-010-oe-2022                                                                   0.264101
# fb-193-tk-010-oe-2022-reordered                                                         0.264101
# fb-195-tk-013-oe-2022-interchange-replace-cache                                         0.000000
# fb-196-ic-0318-oe-2022                                                                  0.000082
#
#                                                  fb-196-ic-0318-oe-2022
# fb-193-tk-010-oe-2022                                          0.264143
# fb-193-tk-010-oe-2022-reordered                                0.264143
# fb-195-tk-013-oe-2022-interchange-replace-cache                0.000081
# fb-196-ic-0318-oe-2022                                         0.000000

# %%
df_58_4 = cross_compare("opt-geo-batch-58", "18438954-4")
df_58_4
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
#                                                     fb-193-tk-010-oe-2022  \
# fb-193-tk-010-oe-2022                                            0.000000
# fb-193-tk-010-oe-2022-reordered                                  0.000004
# fb-195-tk-013-oe-2022-interchange-replace-cache                  0.000008
# fb-195-tk-013-oe-2022-interchange-replace-cache...               0.000008
# fb-196-ic-0318-oe-2022                                           1.666589
#
#                                                     fb-193-tk-010-oe-2022-reordered  \
# fb-193-tk-010-oe-2022                                                      0.000003
# fb-193-tk-010-oe-2022-reordered                                            0.000000
# fb-195-tk-013-oe-2022-interchange-replace-cache                            0.000004
# fb-195-tk-013-oe-2022-interchange-replace-cache...                         0.000004
# fb-196-ic-0318-oe-2022                                                     1.666589
#
#                                                     fb-195-tk-013-oe-2022-interchange-replace-cache  \
# fb-193-tk-010-oe-2022                                                                      0.000006
# fb-193-tk-010-oe-2022-reordered                                                            0.000003
# fb-195-tk-013-oe-2022-interchange-replace-cache                                            0.000000
# fb-195-tk-013-oe-2022-interchange-replace-cache...                                         0.000000
# fb-196-ic-0318-oe-2022                                                                     1.666589
#
#                                                     fb-195-tk-013-oe-2022-interchange-replace-cache-switching  \
# fb-193-tk-010-oe-2022                                                                    5.913733e-06
# fb-193-tk-010-oe-2022-reordered                                                          2.604480e-06
# fb-195-tk-013-oe-2022-interchange-replace-cache                                          1.040544e-07
# fb-195-tk-013-oe-2022-interchange-replace-cache...                                       0.000000e+00
# fb-196-ic-0318-oe-2022                                                                   1.666589e+00
#
#                                                     fb-196-ic-0318-oe-2022
# fb-193-tk-010-oe-2022                                             1.591251
# fb-193-tk-010-oe-2022-reordered                                   1.591251
# fb-195-tk-013-oe-2022-interchange-replace-cache                   1.591251
# fb-195-tk-013-oe-2022-interchange-replace-cache...                1.591251
# fb-196-ic-0318-oe-2022                                            0.000000

# %%
get_rmsd(
    "opt-geo-batch-19",
    "18434757-17",
    project_a="001_fit-all",
    environment_a="fb-193-tk-010-oe-2022",
    replicate_a="rep1",
    project_b="001_fit-all",
    environment_b="fb-195-tk-013-oe-2022-interchange-replace-cache",
    replicate_b="rep1",
)
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# (0.30625010957393206, 0.3045961832493517)

# %%
get_rmsd(
    "opt-geo-batch-19",
    "18434757-17",
    project_a="001_fit-all",
    environment_a="fb-193-tk-010-oe-2022",
    replicate_a="rep1",
    project_b="001_fit-all",
    environment_b="fb-196-ic-0318-oe-2022",
    replicate_b="rep1",
)
# Out:
# (0.30619653517378803, 0.30453992102407207)

# %%
get_rmsd(
    "opt-geo-batch-19",
    "18434757-17",
    project_a="001_fit-all",
    environment_a="fb-193-tk-010-oe-2022",
    replicate_a="rep1",
    project_b="001_fit-all",
    environment_b="fb-193-tk-010-oe-2022-reordered",
    replicate_b="rep1",
)
# Out:
# (0.5427040210800871, 8.041106202144648e-07)

# %% [markdown]
# ## Make targets smaller
