# %%
import re
import pathlib
import tqdm
import numpy as np
import pandas as pd

# %%
def get_smiles(batch_name: str, target_name: str, indicate_log: str):
    from openff.toolkit.topology import Molecule
    
    indicate_log = pathlib.Path(indicate_log)
    target_directory = indicate_log.parent.parent.parent.parent / "targets"
    
    if batch_name.startswith("opt"):
        file = target_directory / batch_name / f"{target_name}.sdf"
    else:
        file = target_directory / target_name / "input.sdf"
    
    mol = Molecule.from_file(str(file.resolve()), "SDF", allow_undefined_stereo=True)
    return mol.to_smiles(mapped=True), mol.to_smiles()

# %%
def read_directory():
    import pandas as pd
    
    here = pathlib.Path(".")
    indicate_logs = sorted(
        here.glob("*/*/*/optimize.tmp/*/iter_0000/indicate.log")
    )
    
    data = {
        "Experiment": [],
        "Environment": [],
        "Replicate": [],
        "Target type": [],
        "Batch": [],
        "Target name": [],
        "QCArchive ID": [],
        "Batch ID": [],
        "Mapped SMILES": [],
        "SMILES": [],
        "Term": [],
        
    }
    for logfile in tqdm.tqdm(indicate_logs):
        with logfile.open("r") as f:
            contents = [x.strip() for x in f.readlines()]
        for line in contents:
            fields = line.split()
            if not fields or not len(re.findall("-", fields[0])) == 1:
                continue
            name = fields[0]
            if name.startswith("torsion"):
                qcarchive_id = name.split("-")[1]
                batch_id = -1
                term_type = "torsion"
            else:
                qcarchive_id, batch_id = name.split("-")
                term_type = "optgeo"
                
            batch_name = logfile.parent.parent.stem
            term = float(fields[-1])
            mapped_smiles, smiles = get_smiles(batch_name, name, logfile)
            
            rep_directory = logfile.parent.parent.parent.parent
            data["Experiment"].append(rep_directory.parent.parent.stem)
            data["Environment"].append(rep_directory.parent.stem)
            data["Replicate"].append(rep_directory.stem)
            data["Target type"].append(term_type)
            data["Batch"].append(batch_name)
            data["Target name"].append(name)
            data["QCArchive ID"].append(int(qcarchive_id))
            data["Batch ID"].append(int(batch_id))
            data["Mapped SMILES"].append(mapped_smiles)
            data["SMILES"].append(smiles)
            data["Term"].append(term)
            
    
    df = pd.DataFrame(data)
    return df

# %%
df = read_directory()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 94.11it/s]

# %%
df
# Out:
#       Experiment                                        Environment Replicate  \
# 0   01_opt-48-17                              fb-193-tk-010-oe-2022      rep1
# 1   01_opt-48-17                              fb-193-tk-010-oe-2022      rep2
# 2   01_opt-48-17                              fb-193-tk-010-oe-2022      rep3
# 3   01_opt-48-17    fb-195-tk-013-oe-2022-interchange-replace-cache      rep1
# 4   01_opt-48-17    fb-195-tk-013-oe-2022-interchange-replace-cache      rep2
# 5   01_opt-48-17    fb-195-tk-013-oe-2022-interchange-replace-cache      rep3
# 6   02_opt-71-20                              fb-193-tk-010-oe-2022      rep1
# 7   02_opt-71-20                              fb-193-tk-010-oe-2022      rep2
# 8   02_opt-71-20                              fb-193-tk-010-oe-2022      rep3
# 9   02_opt-71-20    fb-195-tk-013-oe-2022-interchange-replace-cache      rep1
# 10  02_opt-71-20    fb-195-tk-013-oe-2022-interchange-replace-cache      rep2
# 11  02_opt-71-20    fb-195-tk-013-oe-2022-interchange-replace-cache      rep3
# 12  02_opt-71-20  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep1
# 13  02_opt-71-20  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep2
# 14  02_opt-71-20  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep3
# 15  03_opt-113-8                              fb-193-tk-010-oe-2022      rep1
# 16  03_opt-113-8                              fb-193-tk-010-oe-2022      rep2
# 17  03_opt-113-8                              fb-193-tk-010-oe-2022      rep3
# 18  03_opt-113-8    fb-195-tk-013-oe-2022-interchange-replace-cache      rep1
# 19  03_opt-113-8    fb-195-tk-013-oe-2022-interchange-replace-cache      rep2
# 20  03_opt-113-8    fb-195-tk-013-oe-2022-interchange-replace-cache      rep3
# 21  03_opt-113-8  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep1
# 22  03_opt-113-8  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep2
# 23  03_opt-113-8  fb-195-tk-013-oe-2022-interchange-replace-cach...      rep3
#
#    Target type              Batch  Target name  QCArchive ID  Batch ID  \
# 0       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 1       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 2       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 3       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 4       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 5       optgeo   opt-geo-batch-48  18437974-17      18437974        17
# 6       optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 7       optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 8       optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 9       optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 10      optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 11      optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 12      optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 13      optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 14      optgeo   opt-geo-batch-71  19094129-20      19094129        20
# 15      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 16      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 17      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 18      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 19      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 20      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 21      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 22      optgeo  opt-geo-batch-113   19095588-8      19095588         8
# 23      optgeo  opt-geo-batch-113   19095588-8      19095588         8
#
#                                         Mapped SMILES  \
# 0   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 1   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 2   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 3   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 4   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 5   [H:20][c:2]1[c:4]([c:8]([c:5]([c:3]([c:7]1[C:1...
# 6   [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 7   [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 8   [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 9   [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 10  [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 11  [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 12  [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 13  [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 14  [H:16][c:1]1[c:2]([c:5]([c:6]([c:3]([c:4]1[C:9...
# 15  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 16  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 17  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 18  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 19  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 20  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 21  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 22  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
# 23  [H:33][c:1]1[c:3]([c:10]([c:11]([c:5]([c:7]1[C...
#
#                                                SMILES      Term
# 0   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...  2097.572
# 1   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...  2097.572
# 2   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...  2097.572
# 3   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...   442.121
# 4   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...   442.121
# 5   [H]c1c(c(c(c(c1C#N)[H])[H])/C(=N/N([H])c2nc(c(...   442.121
# 6   [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   470.715
# 7   [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   470.715
# 8   [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   470.715
# 9   [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 10  [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 11  [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 12  [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 13  [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 14  [H]c1c(c(c(c(c1C([H])([H])C([H])([H])N([H])[H]...   117.418
# 15  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   800.755
# 16  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   800.755
# 17  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   800.755
# 18  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803
# 19  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803
# 20  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803
# 21  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803
# 22  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803
# 23  [H]c1c(c(c(c(c1C2=NC(=C(O2)C([H])([H])[H])C([H...   488.803

# %%
from openmm import unit

# %%
(1.1 * unit.elementary_charge)._value
# Out:
# 1.1
